# %%
import torch
import torchviz
from utils.Models import MLP

model = MLP(input_dim=4, output_dim=2, hidden_layers=2, hidden_dim=64)
dummy_input = torch.randn(10, 4)
graph = torchviz.make_dot(model(dummy_input), params=dict(list(model.named_parameters())))
graph.render("MLP_Model", format="png")  # 保存图表为PNG格式
# Out:
# 'MLP_Model.png'

# %%
from torchsummary import summary
summary(model, (4,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 64]             320
#               ReLU-2                   [-1, 64]               0
#             Linear-3                   [-1, 64]           4,160
#        BatchNorm1d-4                   [-1, 64]             128
#               ReLU-5                   [-1, 64]               0
#             Linear-6                   [-1, 64]           4,160
#        BatchNorm1d-7                   [-1, 64]             128
#               ReLU-8                   [-1, 64]               0
#             Linear-9                    [-1, 2]             130
# ================================================================
# Total params: 9,026
# Trainable params: 9,026
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.04
# ----------------------------------------------------------------

# %%
from torchinfo import summary

model = MLP(input_dim=4, output_dim=2, hidden_layers=2, hidden_dim=64)
summary(model, input_size=(10, 4))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLP                                      [10, 2]                   --
# ├─Linear: 1-1                            [10, 64]                  320
# ├─ReLU: 1-2                              [10, 64]                  --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─Sequential: 2-1                   [10, 64]                  --
# │    │    └─Linear: 3-1                  [10, 64]                  4,160
# │    │    └─BatchNorm1d: 3-2             [10, 64]                  128
# ├─ReLU: 1-4                              [10, 64]                  --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─Sequential: 2-2                   [10, 64]                  --
# │    │    └─Linear: 3-3                  [10, 64]                  4,160
# │    │    └─BatchNorm1d: 3-4             [10, 64]                  128
# ├─ReLU: 1-6                              [10, 64]                  --
# ├─Linear: 1-7                            [10, 2]                   130
# ==========================================================================================
# Total params: 9,026
# Trainable params: 9,026
# Non-trainable params: 0
# Total mult-adds (M): 0.09
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.06
# ==========================================================================================

# %%
from utils.unet import UNetModel
from torchinfo import summary

image_size = 64
image_channels = 1
num_channels = 64
num_res_blocks = 4
num_heads = 4
num_heads_upsample = -1
attention_resolutions = "8"
dropout = 0.1
use_checkpoint = False
use_scale_shift_norm = True

channel_mult = (1, 2, 4)

attention_ds = []
for res in attention_resolutions.split(","):
    attention_ds.append(image_size // int(res))
kwargs = {
    "in_channels": image_channels,
    "model_channels": num_channels,
    "out_channels": image_channels,
    "num_res_blocks": num_res_blocks,
    "attention_resolutions": tuple(attention_ds),
    "dropout": dropout,
    "channel_mult": channel_mult,
    "num_classes": None,
    "use_checkpoint": use_checkpoint,
    "num_heads": num_heads,
    "num_heads_upsample": num_heads_upsample,
    "use_scale_shift_norm": use_scale_shift_norm,
}

unet = UNetModel(**kwargs)
x = torch.rand(3, 1, 64, 64)
t = torch.rand(3)
d = torch.rand(3)
summary(unet, input_data=[x,t,d],batch_dim=0)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# UNetModel                                     [3, 1, 64, 64]            --
# ├─Sequential: 1-1                             [3, 256]                  --
# │    └─Linear: 2-1                            [3, 256]                  16,640
# │    └─SiLU: 2-2                              [3, 256]                  --
# │    └─Linear: 2-3                            [3, 256]                  65,792
# ├─Sequential: 1-2                             [3, 256]                  --
# │    └─Linear: 2-4                            [3, 256]                  16,640
# │    └─SiLU: 2-5                              [3, 256]                  --
# │    └─Linear: 2-6                            [3, 256]                  65,792
# ├─ModuleList: 1-3                             --                        --
# │    └─TimestepEmbedSequential: 2-7           [3, 64, 64, 64]           --
# │    │    └─Conv2d: 3-1                       [3, 64, 64, 64]           640
# │    └─TimestepEmbedSequential: 2-8           [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-2                     [3, 64, 64, 64]           107,008
# │    └─TimestepEmbedSequential: 2-9           [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-3                     [3, 64, 64, 64]           107,008
# │    └─TimestepEmbedSequential: 2-10          [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-4                     [3, 64, 64, 64]           107,008
# │    └─TimestepEmbedSequential: 2-11          [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-5                     [3, 64, 64, 64]           107,008
# │    └─TimestepEmbedSequential: 2-12          [3, 64, 32, 32]           --
# │    │    └─Downsample: 3-6                   [3, 64, 32, 32]           36,928
# │    └─TimestepEmbedSequential: 2-13          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-7                     [3, 128, 32, 32]          295,936
# │    └─TimestepEmbedSequential: 2-14          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-8                     [3, 128, 32, 32]          361,472
# │    └─TimestepEmbedSequential: 2-15          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-9                     [3, 128, 32, 32]          361,472
# │    └─TimestepEmbedSequential: 2-16          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-10                    [3, 128, 32, 32]          361,472
# │    └─TimestepEmbedSequential: 2-17          [3, 128, 16, 16]          --
# │    │    └─Downsample: 3-11                  [3, 128, 16, 16]          147,584
# │    └─TimestepEmbedSequential: 2-18          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-12                    [3, 256, 16, 16]          1,050,624
# │    └─TimestepEmbedSequential: 2-19          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-13                    [3, 256, 16, 16]          1,312,768
# │    └─TimestepEmbedSequential: 2-20          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-14                    [3, 256, 16, 16]          1,312,768
# │    └─TimestepEmbedSequential: 2-21          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-15                    [3, 256, 16, 16]          1,312,768
# ├─TimestepEmbedSequential: 1-4                [3, 256, 16, 16]          --
# │    └─ResBlock: 2-22                         [3, 256, 16, 16]          --
# │    │    └─Sequential: 3-16                  [3, 256, 16, 16]          590,592
# │    │    └─Sequential: 3-17                  [3, 512]                  131,584
# │    │    └─Sequential: 3-18                  --                        590,592
# │    │    └─Identity: 3-19                    [3, 256, 16, 16]          --
# │    └─AttentionBlock: 2-23                   [3, 256, 16, 16]          --
# │    │    └─GroupNorm32: 3-20                 [3, 256, 256]             512
# │    │    └─Conv1d: 3-21                      [3, 768, 256]             197,376
# │    │    └─QKVAttention: 3-22                [12, 64, 256]             --
# │    │    └─Conv1d: 3-23                      [3, 256, 256]             65,792
# │    └─ResBlock: 2-24                         [3, 256, 16, 16]          --
# │    │    └─Sequential: 3-24                  [3, 256, 16, 16]          590,592
# │    │    └─Sequential: 3-25                  [3, 512]                  131,584
# │    │    └─Sequential: 3-26                  --                        590,592
# │    │    └─Identity: 3-27                    [3, 256, 16, 16]          --
# ├─ModuleList: 1-5                             --                        --
# │    └─TimestepEmbedSequential: 2-25          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-28                    [3, 256, 16, 16]          2,034,432
# │    └─TimestepEmbedSequential: 2-26          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-29                    [3, 256, 16, 16]          2,034,432
# │    └─TimestepEmbedSequential: 2-27          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-30                    [3, 256, 16, 16]          2,034,432
# │    └─TimestepEmbedSequential: 2-28          [3, 256, 16, 16]          --
# │    │    └─ResBlock: 3-31                    [3, 256, 16, 16]          2,034,432
# │    └─TimestepEmbedSequential: 2-29          [3, 256, 32, 32]          --
# │    │    └─ResBlock: 3-32                    [3, 256, 16, 16]          1,706,496
# │    │    └─Upsample: 3-33                    [3, 256, 32, 32]          590,080
# │    └─TimestepEmbedSequential: 2-30          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-34                    [3, 128, 32, 32]          706,176
# │    └─TimestepEmbedSequential: 2-31          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-35                    [3, 128, 32, 32]          542,080
# │    └─TimestepEmbedSequential: 2-32          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-36                    [3, 128, 32, 32]          542,080
# │    └─TimestepEmbedSequential: 2-33          [3, 128, 32, 32]          --
# │    │    └─ResBlock: 3-37                    [3, 128, 32, 32]          542,080
# │    └─TimestepEmbedSequential: 2-34          [3, 128, 64, 64]          --
# │    │    └─ResBlock: 3-38                    [3, 128, 32, 32]          460,032
# │    │    └─Upsample: 3-39                    [3, 128, 64, 64]          147,584
# │    └─TimestepEmbedSequential: 2-35          [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-40                    [3, 64, 64, 64]           193,344
# │    └─TimestepEmbedSequential: 2-36          [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-41                    [3, 64, 64, 64]           152,256
# │    └─TimestepEmbedSequential: 2-37          [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-42                    [3, 64, 64, 64]           152,256
# │    └─TimestepEmbedSequential: 2-38          [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-43                    [3, 64, 64, 64]           152,256
# │    └─TimestepEmbedSequential: 2-39          [3, 64, 64, 64]           --
# │    │    └─ResBlock: 3-44                    [3, 64, 64, 64]           152,256
# ├─Sequential: 1-6                             [3, 1, 64, 64]            --
# │    └─GroupNorm32: 2-40                      [3, 64, 64, 64]           128
# │    └─SiLU: 2-41                             [3, 64, 64, 64]           --
# │    └─Conv2d: 2-42                           [3, 1, 64, 64]            577
# ===============================================================================================
# Total params: 24,213,953
# Trainable params: 24,213,953
# Non-trainable params: 0
# Total mult-adds (G): 38.79
# ===============================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 570.50
# Params size (MB): 96.86
# Estimated Total Size (MB): 667.41
# ===============================================================================================
